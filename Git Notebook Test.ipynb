# %%
# %sql

CREATE SCHEMA CB_Prod

# %%
# %sql


DROP TABLE IF EXISTS CB_Prod.tbl_File_Share_Data;

CREATE TABLE CB_Prod.tbl_File_Share_Data 
(
        ID BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1), FilePath varchar(500)
    
    );
